# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib notebook

im = mpimg.imread(r'C:\Users\sparsonslab\Documents\programming\jupyter_notebooks\iseries.jpg')

plt.imshow(im)
# Out:
# <img src="data:image/png;base64,..." width="1005">
